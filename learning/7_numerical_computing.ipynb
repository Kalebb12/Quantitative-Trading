# %% [markdown]
# ## **Numerical Computing with Numpy**

# %%
v = [10,20,30]
m = [v,v,v]
m
# Out:
# [[10, 20, 30], [10, 20, 30], [10, 20, 30]]

# %%
v[0] = "python"
m
# Out:
# [['python', 20, 30], ['python', 20, 30], ['python', 20, 30]]

# %%
from copy import deepcopy

# %%
v[0] = 10
m = deepcopy(v)

# %%
m
# Out:
# [10, 20, 30]

# %%
v[0] = "python"

# %%
m
# Out:
# [10, 20, 30]

# %%
import array
a = array.array("f",[0.4,0.5,0.6])
a
# Out:
# array('f', [0.4000000059604645, 0.5, 0.6000000238418579])

# %%
a.append(2.0)
a
# Out:
# array('f', [0.4000000059604645, 0.5, 0.6000000238418579, 2.0, 2.0])

# %%
a.tolist()
# Out:
# [0.4000000059604645, 0.5, 0.6000000238418579, 2.0]

# %% [markdown]
# ## numpy

# %%
import numpy as np

# %%
a = np.array([0,0.5,1.0])
a
# Out:
# array([0. , 0.5, 1. ])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a = np.array(["A","b"])
a
# Out:
# array(['A', 'b'], dtype='<U1')

# %%
a = np.arange(2, 20, 2)
a
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16, 18])

# %%
a.sum()
# Out:
# np.int64(90)

# %%
a.std()
# Out:
# np.float64(5.163977794943222)

# %%
a.cumsum()
# Out:
# array([ 2,  6, 12, 20, 30, 42, 56, 72, 90])

# %%
x = [2,3,4]
2 * x
# Out:
# [2, 3, 4, 2, 3, 4]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16, 18])

# %%
2 * a
# Out:
# array([ 4,  8, 12, 16, 20, 24, 28, 32, 36])

# %%
2 ** a
# Out:
# array([     4,     16,     64,    256,   1024,   4096,  16384,  65536,
#        262144])

# %% [markdown]
# ## universal functions

# %%
np.exp(a)
# Out:
# array([7.38905610e+00, 5.45981500e+01, 4.03428793e+02, 2.98095799e+03,
#        2.20264658e+04, 1.62754791e+05, 1.20260428e+06, 8.88611052e+06,
#        6.56599691e+07])

# %%
np.sqrt(2.5)
# Out:
# np.float64(1.5811388300841898)

# %%
import math
math.sqrt(2.5)
# Out:
# 1.5811388300841898

# %%
math.sqrt(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 math.sqrt(a)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
np.sqrt(a)
# Out:
# array([1.41421356, 2.        , 2.44948974, 2.82842712, 3.16227766,
#        3.46410162, 3.74165739, 4.        , 4.24264069])

# %%
# %timeit math.sqrt(2.5)
# Out:
# 32.1 ns ± 1.41 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit np.sqrt(2.5)
# Out:
# 685 ns ± 20.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## multiple dimensions

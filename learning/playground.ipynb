# %%
list(map(lambda x : x ** 0, [0]))
# Out:
# [1]

# %%
def f(x):
    return x//2

list(map(f,range(10)))
# Out:
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 4]

# %%
def even(x):
    return x % 2 == 0

list(filter(even, range(10)))
# Out:
# [0, 2, 4, 6, 8]

# %%
d = {"Name": "Caleb", "Age":21}
d.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
d.values()
# Out:
# dict_values(['Caleb', 21])

# %%
d.items()
# Out:
# dict_items([('Name', 'Caleb'), ('Age', 21)])

# %%
for item in d.items():
    print(item)
# Out:
# ('Name', 'Caleb')
# ('Age', 21)

# %%
import pandas as pd

# %%
data = pd.read_csv("../fxcm_eur_usd_eod_data.csv")

# %%
data.head()
# Out:
#        Date      Time  OpenBid  HighBid   LowBid  CloseBid  OpenAsk  HighAsk  \
# 0  6/3/2007  21:00:00  1.34456  1.34986  1.34316   1.34886  1.34474  1.35004
# 1  6/4/2007  21:00:00  1.34886  1.35536  1.34876   1.35226  1.34904  1.35554
# 2  6/5/2007  21:00:00  1.35226  1.35376  1.34846   1.35026  1.35244  1.35394
# 3  6/6/2007  21:00:00  1.35026  1.35116  1.34216   1.34326  1.35044  1.35134
# 4  6/7/2007  21:00:00  1.34326  1.34356  1.33196   1.33676  1.34344  1.34374
#
#     LowAsk  CloseAsk  TotalTicks
# 0  1.34334   1.34904        5259
# 1  1.34894   1.35244        6110
# 2  1.34864   1.35044        5875
# 3  1.34234   1.34344        7361
# 4  1.33214   1.33694        8238

# %%
data.plot(figsize=(10, 12), subplots=True);

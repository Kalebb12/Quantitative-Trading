# %%
list(map(lambda x : x ** 0, [0]))
# Out:
# [1]

# %%
def f(x):
    return x//2

list(map(f,range(10)))
# Out:
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 4]

# %%
def even(x):
    return x % 2 == 0

list(filter(even, range(10)))
# Out:
# [0, 2, 4, 6, 8]

# %%
d = {"Name": "Caleb", "Age":21}
d.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
d.values()
# Out:
# dict_values(['Caleb', 21])

# %%
d.items()
# Out:
# dict_items([('Name', 'Caleb'), ('Age', 21)])

# %%
for item in d.items():
    print(item)
# Out:
# ('Name', 'Caleb')
# ('Age', 21)
